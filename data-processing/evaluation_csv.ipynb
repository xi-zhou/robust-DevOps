# %% [markdown]
# # CLICK ME !!! Mount shared folder

# %%
from google.colab import drive
import os

gdrive_path='/content/gdrive/MyDrive/Robust DevOps: Chiemsee/sorted-results'

# This will mount your google drive under 'MyDrive'
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # check if we are in the correct dir

# %%
subdirectories = [d for d in os.listdir(gdrive_path) if os.path.isdir(os.path.join(gdrive_path, d))]
subdirectories
# Out:
# ['alpine',
#  'aos',
#  'bulma',
#  'gatsby',
#  'ionic',
#  'react-beautiful-dnd',
#  'react-hook-form',
#  'uppy',
#  'vuecli',
#  'n8n',
#  'mermaid',
#  'FreeCodeCamp']

# %% [markdown]
# ## Intermediate step

# %%
import os
import pandas as pd
import matplotlib as plt

THRESHOLD = 0

def get_all_csv_files(path):
    # This function will return a list of paths to all csv files in the given path and its subdirectories
    csv_files = []
    for root, dirs, files in os.walk(path):
        for file in files:
            if file.endswith('.csv'):
                csv_files.append(os.path.join(root, file))
    return csv_files

def process():
  # Get all csv files in the working directory and its subdirectories
  csv_files = get_all_csv_files(os.getcwd())
  print(csv_files)

  # Initialize a dataframe with the first CSV file
  # df = pd.read_csv(csv_files[0])

  # Find the "none_none.csv" file
  start_file = "none_none.csv"
  start_file_full_path = None

  for file in csv_files:
      if os.path.basename(file) == start_file:
          start_file_full_path = file
          csv_files.remove(file)
          break

  if start_file_full_path is None:
      raise FileNotFoundError(f"{start_file} not found in the list of csv files.")


  # Initialize a dataframe with the "none_none.csv" file
  df = pd.read_csv(start_file_full_path)

  # Loop over the rest of the CSV files and merge them with the main dataframe
  for file in csv_files:
      df_file = pd.read_csv(file)
      df = pd.merge(df, df_file, on='testcase_name', how='inner')

  df = df.fillna(0)
  #display(df)
  # remove testcase that behave the same as baseline
  mask = (df.drop(columns=['testcase_name', 'none_none']).sub(df['none_none'], axis=0).abs() > 1e-6).any(axis=1)
  #different_from_baseline = df[mask]
  # We mustn't filter because we need all test cases to count correctly and get the total_number of test cases later
  different_from_baseline = df
  #display(different_from_baseline)

  #compute positive and negative difference matix from baseline
  noise_conditions = different_from_baseline.columns.drop(['testcase_name'])
  # Create a copy of the dataframe to store the results
  df_standerlized = different_from_baseline[['testcase_name']].copy()

  # Calculate the difference for each noise condition
  for noise in noise_conditions:
      # if fail rate is lower than baseline
      #lower_than_base = different_from_baseline[noise] < different_from_baseline['none_none']
      #df_standerlized.loc[lower_than_base, noise] = different_from_baseline.loc[lower_than_base, noise] - different_from_baseline.loc[lower_than_base, 'none_none']

      # if fail rate is equal to baseline
      #equal_to_base = different_from_baseline[noise] == different_from_baseline['none_none']
      #df_standerlized.loc[equal_to_base, noise] = 0

      # if fail rate is higher than baseline
      #higher_than_base = different_from_baseline[noise] > different_from_baseline['none_none']
      #df_standerlized.loc[higher_than_base, noise] = different_from_baseline.loc[higher_than_base, noise] - different_from_baseline.loc[higher_than_base, 'none_none']

      # Just calculate the difference for every row, the calculation is the same for higher lower and same
      df_standerlized[noise] = different_from_baseline[noise] - different_from_baseline['none_none']



  df_standerlized = df_standerlized.round(2)

  # Calculate the total number of test cases
  total_test_cases = df_standerlized.shape[0]

  #display(df_standerlized)
  #print(f"Total test cases: {total_test_cases}")

  # Get the noise type columns (all columns except for "testcase_name" and "none_none")
  noise_types = [column for column in df_standerlized.columns if column not in ["testcase_name", "none_none"]]

  # Initialize a dictionary to store the results
  results = {noise_type: {} for noise_type in noise_types}

  # Calculate the counts and ratios for each noise type
  for noise_type in noise_types:
      for rate_type, condition in zip(["positive", "negative", "zero"], [df_standerlized[noise_type] > THRESHOLD, df_standerlized[noise_type] < -THRESHOLD, abs(df_standerlized[noise_type]) <= THRESHOLD]):
          count = df_standerlized[condition].shape[0]
          if total_test_cases != 0:
            ratio = (count / total_test_cases) * 100  # Convert to percentage
          else:
            ratio = float('nan')

          # Store the results
          results[noise_type][rate_type] = count
          results[noise_type]["ratio_" + rate_type] = ratio

  # Convert the results dictionary to a DataFrame for better visualization
  results_df = pd.DataFrame(results)
  results_df =results_df.round(2)
  transposed_df = results_df.transpose()

  # export result
  transposed_df.to_csv(os.getcwd()+".csv", index=True)

# %% [markdown]
# # CLICK ME!!! Iterate over each subdirectory

# %%
for subdirectory in subdirectories:
    # Change directory to the current subdirectory
    #if subdirectory != "bulma":
    #  continue
    os.chdir(os.path.join(gdrive_path, subdirectory))
    print(f"process project {subdirectory}")
    process()
# Out:
# process project alpine
# ['/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/cpu-high/cpu_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/cpu-low/cpu_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/io-low/io_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/cpu-medium/cpu_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/io-high/io_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/netdelay-high/netdelay_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/io-medium/io_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/netbandwidth-low/netbandwidth_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/netbandwidth-high/netbandwidth_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/netbandwidth-medium/netbandwidth_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/netdelay-low/netdelay_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/netdelay-medium/netdelay_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/none-none/none_none.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/ram-high/ram_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/netpgk-low/netpgk_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/netpgk-high/netpgk_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/ram-medium/ram_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/ram-low/ram_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/alpine/netpgk-medium/netpgk_medium.csv']
# process project aos
# ['/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/cpu-high/cpu_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/io-medium/io_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/netbandwidth-medium/netbandwidth_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/io-high/io_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/netbandwidth-low/netbandwidth_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/cpu-low/cpu_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/netdelay-high/netdelay_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/io-low/io_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/netbandwidth-high/netbandwidth_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/cpu-medium/cpu_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/ram-high/ram_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/netpgk-medium/netpgk_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/netpgk-low/netpgk_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/netpgk-high/netpgk_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/ram-low/ram_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/ram-medium/ram_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/netdelay-low/netdelay_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/none-none/none_none.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/aos/netdelay-medium/netdelay_medium.csv']
# process project bulma
# ['/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/netbandwidth-low/netbandwidth_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/cpu-medium/cpu_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/cpu-high/cpu_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/io-high/io_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/netbandwidth-high/netbandwidth_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/io-low/io_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/netbandwidth-medium/netbandwidth_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/netdelay-high/netdelay_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/cpu-low/cpu_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/io-medium/io_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/netdelay-medium/netdelay_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/netpgk-low/netpgk_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/netdelay-low/netdelay_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/ram-low/ram_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/ram-high/ram_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/netpgk-medium/netpgk_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/ram-medium/ram_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/none-none/none_none.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/bulma/netpgk-high/netpgk_high.csv']
# process project gatsby
# ['/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/io-low/io_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/netbandwidth-high/netbandwidth_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/cpu-low/cpu_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/netdelay-high/netdelay_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/netbandwidth-low/netbandwidth_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/netbandwidth-medium/netbandwidth_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/io-medium/io_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/cpu-high/cpu_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/io-high/io_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/cpu-medium/cpu_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/netpgk-high/netpgk_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/ram-high/ram_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/netpgk-medium/netpgk_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/none-none/none_none.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/netpgk-low/netpgk_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/ram-medium/ram_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/ram-low/ram_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/netdelay-medium/netdelay_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/gatsby/netdelay-low/netdelay_low.csv']
# process project ionic
# ['/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/io-medium/io_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/netbandwidth-high/netbandwidth_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/io-low/io_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/netbandwidth-low/netbandwidth_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/cpu-high/cpu_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/netdelay-high/netdelay_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/cpu-low/cpu_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/io-high/io_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/cpu-medium/cpu_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/netbandwidth-medium/netbandwidth_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/netpgk-high/netpgk_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/ram-low/ram_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/netdelay-medium/netdelay_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/ram-medium/ram_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/ram-high/ram_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/netpgk-low/netpgk_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/netdelay-low/netdelay_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/netpgk-medium/netpgk_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/ionic/none-none/none_none.csv']
# process project react-beautiful-dnd
# ['/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/cpu-medium/cpu_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/io-low/io_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/io-high/io_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/netbandwidth-high/netbandwidth_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/netbandwidth-low/netbandwidth_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/cpu-low/cpu_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/netdelay-high/netdelay_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/io-medium/io_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/netbandwidth-medium/netbandwidth_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/cpu-high/cpu_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/ram-medium/ram_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/ram-low/ram_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/none-none/none_none.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/netdelay-medium/netdelay_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/ram-high/ram_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/netdelay-low/netdelay_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/netpgk-medium/netpgk_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/netpgk-low/netpgk_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-beautiful-dnd/netpgk-high/netpgk_high.csv']
# process project react-hook-form
# ['/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/cpu-low/cpu_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/io-high/io_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/io-medium/io_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/netbandwidth-low/netbandwidth_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/cpu-high/cpu_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/netbandwidth-medium/netbandwidth_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/netbandwidth-high/netbandwidth_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/netdelay-high/netdelay_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/io-low/io_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/cpu-medium/cpu_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/netpgk-high/netpgk_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/netpgk-medium/netpgk_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/ram-medium/ram_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/netdelay-medium/netdelay_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/none-none/none_none.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/netpgk-low/netpgk_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/ram-low/ram_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/ram-high/ram_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/react-hook-form/netdelay-low/netdelay_low.csv']
# process project uppy
# ['/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/netbandwidth-high/netbandwidth_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/netbandwidth-low/netbandwidth_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/cpu-low/cpu_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/io-medium/io_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/netdelay-high/netdelay_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/io-high/io_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/io-low/io_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/netbandwidth-medium/netbandwidth_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/cpu-high/cpu_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/cpu-medium/cpu_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/ram-medium/ram_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/ram-low/ram_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/netpgk-low/netpgk_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/netpgk-high/netpgk_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/none-none/none_none.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/netdelay-medium/netdelay_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/netpgk-medium/netpgk_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/netdelay-low/netdelay_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/uppy/ram-high/ram_high.csv']
# process project vuecli
# ['/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/io-medium/io_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/netdelay-high/netdelay_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/cpu-high/cpu_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/io-low/io_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/cpu-medium/cpu_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/cpu-low/cpu_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/netbandwidth-high/netbandwidth_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/io-high/io_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/netbandwidth-medium/netbandwidth_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/netbandwidth-low/netbandwidth_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/none-none/none_none.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/ram-medium/ram_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/netpgk-medium/netpgk_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/ram-high/ram_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/ram-low/ram_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/netdelay-medium/netdelay_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/netdelay-low/netdelay_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/netpgk-low/netpgk_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/vuecli/netpgk-high/netpgk_high.csv']
# process project n8n
# ['/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/netbandwidth-low/netbandwidth_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/netbandwidth-high/netbandwidth_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/io-high/io_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/cpu-low/cpu_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/cpu-medium/cpu_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/io-medium/io_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/io-low/io_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/netbandwidth-medium/netbandwidth_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/cpu-high/cpu_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/netdelay-high/netdelay_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/netdelay-medium/netdelay_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/none-none/none_none.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/netdelay-low/netdelay_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/netpgk-medium/netpgk_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/netpgk-low/netpgk_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/ram-high/ram_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/ram-medium/ram_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/netpgk-high/netpgk_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/n8n/ram-low/ram_low.csv']
# process project mermaid
# ['/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/cpu-high/cpu_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/cpu-low/cpu_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/io-high/io_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/netbandwidth-low/netbandwidth_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/netdelay-low/netdelay_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/io-medium/io_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/netdelay-high/netdelay_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/io-low/io_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/netbandwidth-medium/netbandwidth_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/cpu-medium/cpu_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/netbandwidth-high/netbandwidth_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/netdelay-medium/netdelay_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/ram-medium/ram_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/ram-high/ram_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/netpgk-medium/netpgk_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/netpgk-low/netpgk_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/netpgk-high/netpgk_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/ram-low/ram_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/mermaid/none-none/none_none.csv']
# process project FreeCodeCamp
# ['/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/io-low/io_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/netbandwidth-high/netbandwidth_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/netdelay-high/netdelay_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/netbandwidth-low/netbandwidth_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/cpu-high/cpu_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/cpu-low/cpu_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/io-high/io_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/netbandwidth-medium/netbandwidth_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/io-medium/io_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/cpu-medium/cpu_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/ram-medium/ram_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/none-none/none_none.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/ram-high/ram_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/netpgk-high/netpgk_high.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/netpgk-medium/netpgk_medium.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/netdelay-low/netdelay_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/ram-low/ram_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/netpgk-low/netpgk_low.csv', '/content/gdrive/.shortcut-targets-by-id/16r1npLT-GjEiuoxB0LJqRJNvLv1UIep1/Robust DevOps: Chiemsee/sorted-results/FreeCodeCamp/netdelay-medium/netdelay_medium.csv']
